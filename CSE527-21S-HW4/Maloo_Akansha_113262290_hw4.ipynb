# %% [markdown]
# # CSE527 Homework 4
# **Due date: 23:59 on April 24, 2021 (Sat.)**
#
# In this semester, we will use Google Colab for the assignments, which allows us to utilize resources that some of us might not have in their local machines such as GPUs. You will need to use your Stony Brook (*.stonybrook.edu) account for coding and Google Drive to save your results.
#
# ## Google Colab Tutorial
# ---
# Go to https://colab.research.google.com/notebooks/, you will see a tutorial named "Welcome to Colaboratory" file, where you can learn the basics of using google colab.
#
# Settings used for assignments: ***Edit -> Notebook Settings -> Runtime Type (Python 3)***.
#
#
# ## Description
# ---
# This project is an introduction to deep learning tools for computer vision. You will design and train deep convolutional networks for scene recognition using [PyTorch](http://pytorch.org). You can visualize the
# structure of the network with [mNeuron] (http://vision03.csail.mit.edu/cnn_art/index.html)
#
# In Problem 1 of the project you will train a deep convolutional network from scratch to recognize scenes. The starter codes gives you methods to load data and display them. You will need to define a simple network architecture and add jittering, normalization, and regularization to increase recognition accuracy to 50, 60, or perhaps 70%. Unfortunately, we only have 2,400 training examples so it doesn't seem possible to train a network from scratch which outperforms hand-crafted features
#
# For Problem 2 you will instead fine-tune a pre-trained deep network to achieve about 85% accuracy on the task. We will use the pretrained AlexNet network which was not trained to recognize scenes at all.
#
# These two approaches represent the most common approaches to recognition problems in computer vision today -- train a deep network from scratch if you have enough data (it's not always obvious whether or not you do), and if you cannot then instead fine-tune a pre-trained network.
#
# There are 2 problems in this homework with a total of 120 points including 20 bonus points. Be sure to read **Submission Guidelines** below. They are important. For the problems requiring text descriptions, you might want to add a markdown block for that.
#
# ## Dataset
# ---
# Save the [dataset(click me)](https://drive.google.com/open?id=1NWC3TMsXSWN2TeoYMCjhf2N1b-WRDh-M) into your working folder in your Google Drive for this homework. <br>
# Under your root folder, there should be a folder named "data" (i.e. XXX/Surname_Givenname_SBUID/data) containing the images.
# **Do not upload** the data subfolder before submitting on blackboard due to size limit. There should be only one .ipynb file under your root folder Surname_Givenname_SBUID.
#
# ## Some Tutorials (PyTorch)
# ---
# - You will be using PyTorch for deep learning toolbox (follow the [link](http://pytorch.org) for installation).
# - For PyTorch beginners, please read this [tutorial](http://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html) before doing your homework.
# - Feel free to study more tutorials at http://pytorch.org/tutorials/.
# - Find cool visualization here at http://playground.tensorflow.org.

# %%
# import packages here
import cv2
import numpy as np
import matplotlib.pyplot as plt
import glob
import random 
import time

import torch
import torchvision
import torchvision.transforms as transforms

from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F

# %%
# Mount your google drive where you've saved your assignment folder
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Set your working directory (in your google drive)
#   change it to your specific homework directory.
# %cd '/content/gdrive/My Drive/Maloo_Akansha_113262290_hw4'
# Out:
# /content/gdrive/My Drive/Maloo_Akansha_113262290_hw4

# %% [markdown]
# ## Problem 0: Loading and Preprocessing data
# ---
# (0 point) In this part, you are provided with a function that loads data into minibatches for training and testing in PyTorch. However, some preprocessing parts are missing. Your will need to implement them when doing Problem 1.

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------

def set_random_seed(seed):
     torch.manual_seed(seed)
     torch.cuda.manual_seed_all(seed)
     np.random.seed(seed)
     random.seed(seed)
     torch.backends.cudnn.deterministic = True
set_random_seed(0)

class_names = [name[13:] for name in glob.glob('./data/train/*')]
class_names = dict(zip(range(len(class_names)), class_names))
print("class_names: %s " % class_names)

def load_dataset(path, img_size, num_per_class=-1, batch_size=16, shuffle=False,
           augment=False, is_color=False, zero_centered=False):    
    data = []
    labels = []    
    channel_num = 3 if is_color else 1
        
    # read images and resizing
    for id, class_name in class_names.items():
        print("Loading images from class: %s" % id)
        img_path_class = glob.glob(path + class_name + '/*.jpg')
        if num_per_class > 0:
            img_path_class = img_path_class[:num_per_class]
        labels.extend([id]*len(img_path_class))
        for filename in img_path_class:
            if is_color:
                img = cv2.imread(filename)
            else:
                img = cv2.imread(filename, 0)
            
            # resize the image
            img = cv2.resize(img, img_size, cv2.INTER_LINEAR)
            
            if is_color:
                img = np.transpose(img, [2, 0, 1])
            
            # norm pixel values to [-1, 1]
            data.append(img.astype(np.float)/255*2-1)
            
    ##########--WRITE YOUR CODE HERE--##########
    # Data Augmentation 
    if augment: 
      flip_data = []
      flip_labels = []
      for i, img in enumerate(data):
        horizontal_flip = cv2.flip(img, 1)
        flip_data.append(horizontal_flip)
        flip_labels.append(labels[i])
      data.extend(flip_data)
      labels.extend(flip_labels)


    ##########-------END OF CODE-------##########    
    
    ##########--WRITE YOUR CODE HERE--##########
    # Data Normalization
    if zero_centered:
      mean_img = np.mean(data, axis=0)
      for i, img in enumerate(data):
        data[i] = img - mean_img


        
    ##########-------END OF CODE-------##########
         
    # randomly permute (this step is important for training)
    if shuffle:
        bundle = list(zip(data, labels))
        random.shuffle(bundle)
        data, labels = zip(*bundle)
    
    # divide data into minibatches of TorchTensors
    if batch_size > 1:
        batch_data = []
        batch_labels = []
         
        for i in range(int(len(data) / batch_size)):
            minibatch_d = data[i*batch_size: (i+1)*batch_size]
            minibatch_d = np.reshape(minibatch_d, (batch_size, channel_num, img_size[0], img_size[1]))
            batch_data.append(torch.from_numpy(minibatch_d))

            minibatch_l = labels[i*batch_size: (i+1)*batch_size]
            batch_labels.append(torch.LongTensor(minibatch_l))
        data, labels = batch_data, batch_labels 
    
    return zip(batch_data, batch_labels)
# Out:
# class_names: {0: 'Forest', 1: 'Industrial', 2: 'Flower', 3: 'Coast', 4: 'InsideCity', 5: 'Office', 6: 'Bedroom', 7: 'Highway', 8: 'Street', 9: 'TallBuilding', 10: 'LivingRoom', 11: 'Suburb', 12: 'OpenCountry', 13: 'Mountain', 14: 'Kitchen', 15: 'Store'}

# %%
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 37 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
# show some images
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    if len(npimg.shape) > 2:
        npimg = np.transpose(img, [1, 2, 0])
    plt.figure
    plt.imshow(npimg, 'gray')
    plt.show()
img, label = trainloader_small[0][0][11][0], trainloader_small[0][1][11]
label = int(np.array(label))
print(class_names[label])
imshow(img)
# Out:
# Store

# %% [markdown]
# ## Problem 1: Training a Network From Scratch
# Gone are the days of hand designed features. Now we have end-to-end learning in which a highly non-linear representation is learned for our data to maximize our objective function (in this case, 16-way classification accuracy). Let's start!

# %% [markdown]
# First, let's define a simpe network architecture.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class TNet(nn.Module):
    def __init__(self):
      super(TNet,self).__init__()  
           
      self.features = torch.nn.Sequential(
        nn.Conv2d(1, 16, 3), #padding
        nn.ReLU(),
        nn.MaxPool2d(4, stride=4), 
      )
      
      self.classifier = nn.Sequential(
         nn.Linear(3600, 16), 
      )
      
    def forward(self, x):
      x = self.features(x)  
      x = torch.flatten(x, 1)
      x = self.classifier(x)
      return x

# %% [markdown]
# Then, let's define model training and evaluation functions.

# %%
#--------------------------------------------------
#       Model Training Function
#--------------------------------------------------
import torch.optim as optim
import time
  
def trainModel(net, trainloader, train_option, testloader=None):  
  loss_func = nn.CrossEntropyLoss()
  lr = train_option['lr']
  epoch = train_option['epoch']
  device = train_option['device'] if 'device' in train_option.keys() else 'cpu'
  log_iter = train_option['log_iter'] if 'log_iter' in train_option.keys() else 20
  eval_epoch = 1
  
  if 'optimizer' in train_option.keys():
    optimizer = train_option['optimizer']
  else:
    optimizer = optim.Adam(net.parameters(), lr=lr)

  start_time = time.time()
  if device == 'gpu':
    net = net.cuda()
    
  iters = 0
  running_loss = 0.0
  for ep in range(epoch):
    net.train()        
    for iter, (x, y) in enumerate(trainloader):
      iters += 1
      batch_x = Variable(x).float()
      batch_y = Variable(y).long()
      if device == 'gpu':
        batch_x = batch_x.cuda()
        batch_y = batch_y.cuda()

      outputs = net(batch_x)
      loss = loss_func(outputs, batch_y)
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()
      running_loss += loss.item()
      
      time_lapse = time.strftime('%H:%M:%S', time.gmtime(time.time() - start_time))
      if iter % log_iter == 0:
        print('Epoch:{:2d} | Iter:{:5d} | Time: {} | Train Loss: {:.4f} | Average Loss: {:.4f} '.format(ep+1, iter, time_lapse, loss.item(), running_loss/iters))
   
    if testloader is not None and ep % eval_epoch == 0:
      evalModel(net, testloader)

# %%
#--------------------------------------------------
#       Model Evaluating Function
#--------------------------------------------------
import time
  
def evalModel(net, testloader): 
  acc = 0.0
  count = 0
  start_time = time.time()
  device = 'gpu' if next(net.parameters()).is_cuda else 'cpu'
  net.eval()
  
  for iter, (x, y) in enumerate(testloader):
        count += x.shape[0]
        batch_x = Variable(x).float()
        batch_y = Variable(y).long()
        if device == 'gpu':
          batch_x = batch_x.cuda()
          batch_y = batch_y.cuda()
        outputs = net(batch_x)
        acc += torch.sum(outputs.max(1)[1]==batch_y)
        
  time_lapse = time.strftime('%H:%M:%S', time.gmtime(time.time() - start_time))        
  print('Accuracy: {:5f} | Time: {}'.format(acc/count,time_lapse))

# %% [markdown]
# Finally, let's start training and evaluation.

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = TNet() 
train_option = {}
train_option['lr'] = 0.002
train_option['epoch'] = 20
train_option['device'] = 'gpu'
trainModel(net, trainloader_small, train_option, testloader_small)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.7706 | Average Loss: 2.7706
# Epoch: 1 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.7727 | Average Loss: 2.7502
# Epoch: 1 | Iter:   40 | Time: 00:00:00 | Train Loss: 2.2617 | Average Loss: 2.5419
# Epoch: 1 | Iter:   60 | Time: 00:00:00 | Train Loss: 2.2812 | Average Loss: 2.3900
# Accuracy: 0.385417 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.6432 | Average Loss: 2.3070
# Epoch: 2 | Iter:   20 | Time: 00:00:00 | Train Loss: 1.8433 | Average Loss: 2.1846
# Epoch: 2 | Iter:   40 | Time: 00:00:00 | Train Loss: 1.6472 | Average Loss: 2.1002
# Epoch: 2 | Iter:   60 | Time: 00:00:00 | Train Loss: 1.9353 | Average Loss: 2.0291
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.3363 | Average Loss: 1.9843
# Epoch: 3 | Iter:   20 | Time: 00:00:00 | Train Loss: 1.4831 | Average Loss: 1.9124
# Epoch: 3 | Iter:   40 | Time: 00:00:00 | Train Loss: 1.2896 | Average Loss: 1.8509
# Epoch: 3 | Iter:   60 | Time: 00:00:00 | Train Loss: 1.5457 | Average Loss: 1.7971
# Accuracy: 0.476562 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.1017 | Average Loss: 1.7636
# Epoch: 4 | Iter:   20 | Time: 00:00:00 | Train Loss: 1.2071 | Average Loss: 1.7112
# Epoch: 4 | Iter:   40 | Time: 00:00:00 | Train Loss: 1.0261 | Average Loss: 1.6616
# Epoch: 4 | Iter:   60 | Time: 00:00:00 | Train Loss: 1.2290 | Average Loss: 1.6182
# Accuracy: 0.497396 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.9221 | Average Loss: 1.5911
# Epoch: 5 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.0166 | Average Loss: 1.5503
# Epoch: 5 | Iter:   40 | Time: 00:00:01 | Train Loss: 0.8479 | Average Loss: 1.5098
# Epoch: 5 | Iter:   60 | Time: 00:00:01 | Train Loss: 0.9846 | Average Loss: 1.4740
# Accuracy: 0.507812 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.7798 | Average Loss: 1.4513
# Epoch: 6 | Iter:   20 | Time: 00:00:01 | Train Loss: 0.8797 | Average Loss: 1.4186
# Epoch: 6 | Iter:   40 | Time: 00:00:01 | Train Loss: 0.7302 | Average Loss: 1.3851
# Epoch: 6 | Iter:   60 | Time: 00:00:01 | Train Loss: 0.7913 | Average Loss: 1.3552
# Accuracy: 0.520833 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.6656 | Average Loss: 1.3356
# Epoch: 7 | Iter:   20 | Time: 00:00:01 | Train Loss: 0.7563 | Average Loss: 1.3086
# Epoch: 7 | Iter:   40 | Time: 00:00:01 | Train Loss: 0.6346 | Average Loss: 1.2803
# Epoch: 7 | Iter:   60 | Time: 00:00:01 | Train Loss: 0.6184 | Average Loss: 1.2549
# Accuracy: 0.536458 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.5700 | Average Loss: 1.2379
# Epoch: 8 | Iter:   20 | Time: 00:00:01 | Train Loss: 0.6195 | Average Loss: 1.2149
# Epoch: 8 | Iter:   40 | Time: 00:00:01 | Train Loss: 0.5612 | Average Loss: 1.1907
# Epoch: 8 | Iter:   60 | Time: 00:00:01 | Train Loss: 0.4801 | Average Loss: 1.1687
# Accuracy: 0.528646 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.4928 | Average Loss: 1.1541
# Epoch: 9 | Iter:   20 | Time: 00:00:02 | Train Loss: 0.5308 | Average Loss: 1.1343
# Epoch: 9 | Iter:   40 | Time: 00:00:02 | Train Loss: 0.5240 | Average Loss: 1.1134
# Epoch: 9 | Iter:   60 | Time: 00:00:02 | Train Loss: 0.4050 | Average Loss: 1.0944
# Accuracy: 0.520833 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.4415 | Average Loss: 1.0818
# Epoch:10 | Iter:   20 | Time: 00:00:02 | Train Loss: 0.4997 | Average Loss: 1.0647
# Epoch:10 | Iter:   40 | Time: 00:00:02 | Train Loss: 0.5018 | Average Loss: 1.0465
# Epoch:10 | Iter:   60 | Time: 00:00:02 | Train Loss: 0.3689 | Average Loss: 1.0302
# Accuracy: 0.513021 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.4129 | Average Loss: 1.0196
# Epoch:11 | Iter:   20 | Time: 00:00:02 | Train Loss: 0.5243 | Average Loss: 1.0049
# Epoch:11 | Iter:   40 | Time: 00:00:02 | Train Loss: 0.4719 | Average Loss: 0.9893
# Epoch:11 | Iter:   60 | Time: 00:00:02 | Train Loss: 0.3454 | Average Loss: 0.9751
# Accuracy: 0.523438 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.3689 | Average Loss: 0.9657
# Epoch:12 | Iter:   20 | Time: 00:00:02 | Train Loss: 0.4630 | Average Loss: 0.9525
# Epoch:12 | Iter:   40 | Time: 00:00:02 | Train Loss: 0.3787 | Average Loss: 0.9392
# Epoch:12 | Iter:   60 | Time: 00:00:02 | Train Loss: 0.3280 | Average Loss: 0.9264
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.4533 | Average Loss: 0.9185
# Epoch:13 | Iter:   20 | Time: 00:00:02 | Train Loss: 0.4390 | Average Loss: 0.9076
# Epoch:13 | Iter:   40 | Time: 00:00:03 | Train Loss: 0.4100 | Average Loss: 0.8959
# Epoch:13 | Iter:   60 | Time: 00:00:03 | Train Loss: 0.2299 | Average Loss: 0.8844
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.4391 | Average Loss: 0.8770
# Epoch:14 | Iter:   20 | Time: 00:00:03 | Train Loss: 0.4272 | Average Loss: 0.8661
# Epoch:14 | Iter:   40 | Time: 00:00:03 | Train Loss: 0.3177 | Average Loss: 0.8547
# Epoch:14 | Iter:   60 | Time: 00:00:03 | Train Loss: 0.2339 | Average Loss: 0.8439
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.3537 | Average Loss: 0.8367
# Epoch:15 | Iter:   20 | Time: 00:00:03 | Train Loss: 0.3956 | Average Loss: 0.8269
# Epoch:15 | Iter:   40 | Time: 00:00:03 | Train Loss: 0.2825 | Average Loss: 0.8168
# Epoch:15 | Iter:   60 | Time: 00:00:03 | Train Loss: 0.2166 | Average Loss: 0.8070
# Accuracy: 0.507812 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.2549 | Average Loss: 0.8002
# Epoch:16 | Iter:   20 | Time: 00:00:03 | Train Loss: 0.3712 | Average Loss: 0.7915
# Epoch:16 | Iter:   40 | Time: 00:00:03 | Train Loss: 0.2237 | Average Loss: 0.7821
# Epoch:16 | Iter:   60 | Time: 00:00:03 | Train Loss: 0.2004 | Average Loss: 0.7731
# Accuracy: 0.539062 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.2120 | Average Loss: 0.7668
# Epoch:17 | Iter:   20 | Time: 00:00:03 | Train Loss: 0.3586 | Average Loss: 0.7585
# Epoch:17 | Iter:   40 | Time: 00:00:03 | Train Loss: 0.1900 | Average Loss: 0.7503
# Epoch:17 | Iter:   60 | Time: 00:00:04 | Train Loss: 0.2079 | Average Loss: 0.7422
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.1818 | Average Loss: 0.7364
# Epoch:18 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.2385 | Average Loss: 0.7289
# Epoch:18 | Iter:   40 | Time: 00:00:04 | Train Loss: 0.2916 | Average Loss: 0.7218
# Epoch:18 | Iter:   60 | Time: 00:00:04 | Train Loss: 0.1799 | Average Loss: 0.7145
# Accuracy: 0.539062 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.2179 | Average Loss: 0.7094
# Epoch:19 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.2508 | Average Loss: 0.7024
# Epoch:19 | Iter:   40 | Time: 00:00:04 | Train Loss: 0.2653 | Average Loss: 0.6957
# Epoch:19 | Iter:   60 | Time: 00:00:04 | Train Loss: 0.2427 | Average Loss: 0.6893
# Accuracy: 0.523438 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.2499 | Average Loss: 0.6848
# Epoch:20 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.3369 | Average Loss: 0.6786
# Epoch:20 | Iter:   40 | Time: 00:00:04 | Train Loss: 0.3516 | Average Loss: 0.6728
# Epoch:20 | Iter:   60 | Time: 00:00:04 | Train Loss: 0.3277 | Average Loss: 0.6672
# Accuracy: 0.528646 | Time: 00:00:00

# %% [markdown]
# Great! You would get around 0.45-0.50 accuracy by this very simple network. Now it's your job to beat this result.
#
# ### Problem 1.1
# (35 points) Try to boost the accuracy by doing the following steps:
#
# **Data Augmentation**: We don't have enough training data, let's augment the training data.
# If you **left-right flip (mirror) an image** of a scene, it never changes categories. A kitchen doesn't become a forest when mirrored. This isn't true in all domains — a "d" becomes a "b" when mirrored, so you can't "jitter" digit recognition training data in the same way. But we can synthetically increase our amount of training data by left-right mirroring training images during the learning process.
#
# After you implement mirroring, you should notice that your training error doesn't drop as quickly. That's actually a good thing, because it means the network isn't overfitting to the 2,400 original training images as much (because it sees 4,800 training images now, although they're not as good as 4,800 truly independent samples). Because the training and test errors fall more slowly, you may need more training epochs or you may try modifying the learning rate. You are **required** to implement mirroring as data augmentation for this part.
#
# You can try more elaborate forms of jittering -- zooming in a random amount, rotating a random amount, taking a random crop, etc. These are not required, you might want to try these in the bonus part.
#
# **Data Normalization**: The images aren't **zero-centered**. One simple trick which can help a lot is to subtract the mean from every image. It would arguably be more proper to only compute the mean from the training images (since the test/validation images should be strictly held out) but it won't make much of a difference. This part is **required**.
#
# **Network Regularization**: Add **dropout layer**. If you train your network (especially for more than the default 30 epochs) you'll see that the training error can decrease to zero while the val top1 error hovers at 40% to 50%. The network has learned weights which can perfectly recognize the training data, but those weights don't generalize to held out test data. The best regularization would be more training data but we don't have that. Instead we will use dropout regularization.
#
# What does dropout regularization do? It randomly turns off network connections at training time to fight overfitting. This prevents a unit in one layer from relying too strongly on a single unit in the previous layer. Dropout regularization can be interpreted as simultaneously training many "thinned" versions of your network. At test, all connections are restored which is analogous to taking an average prediction over all of the "thinned" networks. You can see a more complete discussion of dropout regularization in this [paper](https://www.cs.toronto.edu/~hinton/absps/JMLRdropout.pdf).
#
# The dropout layer has only one free parameter — the dropout rate — the proportion of connections that are randomly deleted. The default of 0.5 should be fine. Insert a dropout layer between your convolutional layers. In particular, insert it directly before your last convolutional layer (and try others if that helps). Your train accuracy should decrease much more slowly. That's to be expected — you're making life much harder for the training algorithm by cutting out connections randomly. In this part, you are **required** to add dropout layer to your network.
#
# **Please give detailed descriptions of your network layout in the following format:**<br>
# Data augmentation: [descriptions]<br>
# Data normalization: [descriptions]<br>
# Layer 1: [layer_type]: [Parameters]<br>
# Layer 2: [layer_type]: [Parameters]<br>
# ...<br>
# **Then report the final accuracy on test set.**
#
# The minimum accuracy required for this section is **0.55**.

# %%
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=True, zero_centered=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 75 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------

class Hw4Net(nn.Module):
    def __init__(self):
      super(Hw4Net,self).__init__()  
           
      self.features = torch.nn.Sequential(
        nn.Conv2d(1, 32, 3),
        nn.ReLU(),
        nn.MaxPool2d(4, stride=4), 
        nn.Dropout(0.5)
      )
      
      self.classifier = nn.Sequential(
         nn.Linear(32*15*15, 500), 
         nn.Dropout(0.6),
         nn.Linear(500,32)

      )
      
    def forward(self, x):
      x = self.features(x)  
      # print(x.shape)
      x = torch.flatten(x, 1)
      x = self.classifier(x)
      return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------

hwnet = Hw4Net() 
train_option = {}
train_option['lr'] = 0.002
train_option['epoch'] = 20
train_option['device'] = 'gpu'
print(hwnet)
trainModel(hwnet, trainloader_small, train_option, testloader_small)
# Out:
# Hw4Net(
#   (features): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (3): Dropout(p=0.5, inplace=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=7200, out_features=500, bias=True)
#     (1): Dropout(p=0.6, inplace=False)
#     (2): Linear(in_features=500, out_features=32, bias=True)
#   )
# )
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.4746 | Average Loss: 3.4746
# Epoch: 1 | Iter:   20 | Time: 00:00:00 | Train Loss: 3.6742 | Average Loss: 5.4960
# Epoch: 1 | Iter:   40 | Time: 00:00:00 | Train Loss: 2.5797 | Average Loss: 4.2227
# Epoch: 1 | Iter:   60 | Time: 00:00:00 | Train Loss: 2.4758 | Average Loss: 3.6263
# Accuracy: 0.338542 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.8291 | Average Loss: 3.3714
# Epoch: 2 | Iter:   20 | Time: 00:00:00 | Train Loss: 1.9791 | Average Loss: 3.0885
# Epoch: 2 | Iter:   40 | Time: 00:00:00 | Train Loss: 1.9755 | Average Loss: 2.8805
# Epoch: 2 | Iter:   60 | Time: 00:00:00 | Train Loss: 1.7875 | Average Loss: 2.7110
# Accuracy: 0.427083 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.4379 | Average Loss: 2.6204
# Epoch: 3 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.5811 | Average Loss: 2.4988
# Epoch: 3 | Iter:   40 | Time: 00:00:01 | Train Loss: 1.4241 | Average Loss: 2.3874
# Epoch: 3 | Iter:   60 | Time: 00:00:01 | Train Loss: 1.5337 | Average Loss: 2.2885
# Accuracy: 0.471354 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.3372 | Average Loss: 2.2319
# Epoch: 4 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.0079 | Average Loss: 2.1544
# Epoch: 4 | Iter:   40 | Time: 00:00:01 | Train Loss: 1.3340 | Average Loss: 2.0834
# Epoch: 4 | Iter:   60 | Time: 00:00:01 | Train Loss: 1.2261 | Average Loss: 2.0222
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.2381 | Average Loss: 1.9781
# Epoch: 5 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.0779 | Average Loss: 1.9280
# Epoch: 5 | Iter:   40 | Time: 00:00:02 | Train Loss: 0.9298 | Average Loss: 1.8789
# Epoch: 5 | Iter:   60 | Time: 00:00:02 | Train Loss: 1.2547 | Average Loss: 1.8336
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:02 | Train Loss: 1
| Iter:   20 | Time: 00:00:09 | Train Loss: 0.8620 | Average Loss: 0.9806
# Epoch:20 | Iter:   40 | Time: 00:00:09 | Train Loss: 0.7041 | Average Loss: 0.9743
# Epoch:20 | Iter:   60 | Time: 00:00:09 | Train Loss: 0.6117 | Average Loss: 0.9682
# Accuracy: 0.604167 | Time: 00:00:00

# %% [markdown]
# **Answer**:
#
# Data augmentation: Flip(mirror) images to crete more number of images
#
# Data normalization: Subtract mean from every image.
#
# features:
#
#   (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#
#   (1): ReLU()
#
#   (2): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#
#   (3): Dropout(p=0.5, inplace=False)
#
# classifier:
#
#     (0): Linear(in_features=7200, out_features=500, bias=True)
#
#     (1): Dropout(p=0.6, inplace=False)
#
#     (2): Linear(in_features=500, out_features=32, bias=True)
#
#
#
# Accuray on test set: max 0.611979 at 09 epoch

# %% [markdown]
# ## Problem 1.2
#
# (15 points) Try **three different techniques** taught in the class to increase the accuracy of your model. Such as increasing training data by randomly rotating training images, adding batch normalization, different activation functions (e.g., sigmoid) and model architecture modification. Note that too many layers can do you no good due to insufficient training data. Clearly describe your method and accuracy increase/decrease for each of the three techniques.
#
# The minimum accuracy required for this section is **0.60**. (At least one Technique should achieve this)
#
# ### Technique 1

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=True, zero_centered=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 75 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------

class Hw4NetT1(nn.Module):
    def __init__(self):
      super(Hw4NetT1,self).__init__()  
        
      self.features = torch.nn.Sequential(
          nn.Conv2d(1, 32,3),
          nn.Sigmoid(),
          nn.ReLU(),
          nn.MaxPool2d(4, stride=4), 
          nn.Dropout(0.5),
      )
      
      self.classifier = nn.Sequential(
         nn.Linear(32*15*15, 400), 
         nn.BatchNorm1d(400),
         nn.Linear(400,32),
         nn.Dropout(0.5)
         

      )
      
    def forward(self, x):
      x = self.features(x)
      # print(x.shape)  
      x = torch.flatten(x, 1)
      x = self.classifier(x)
      return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
hwnet_bn = Hw4NetT1() 
train_option = {}
train_option['lr'] = 0.002
train_option['epoch'] = 20
train_option['device'] = 'gpu'
print(hwnet_bn)
trainModel(hwnet_bn, trainloader_small, train_option, testloader_small)
# Out:
# Hw4NetT1(
#   (features): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): Sigmoid()
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (4): Dropout(p=0.5, inplace=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=7200, out_features=400, bias=True)
#     (1): BatchNorm1d(400, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Linear(in_features=400, out_features=32, bias=True)
#     (3): Dropout(p=0.5, inplace=False)
#   )
# )
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.8014 | Average Loss: 3.8014
# Epoch: 1 | Iter:   20 | Time: 00:00:00 | Train Loss: 5.1765 | Average Loss: 4.9142
# Epoch: 1 | Iter:   40 | Time: 00:00:00 | Train Loss: 3.3498 | Average Loss: 4.4234
# Epoch: 1 | Iter:   60 | Time: 00:00:00 | Train Loss: 3.3075 | Average Loss: 4.0602
# Accuracy: 0.111979 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.1624 | Average Loss: 3.8967
# Epoch: 2 | Iter:   20 | Time: 00:00:00 | Train Loss: 3.2413 | Average Loss: 3.7393
# Epoch: 2 | Iter:   40 | Time: 00:00:00 | Train Loss: 2.7661 | Average Loss: 3.6177
# Epoch: 2 | Iter:   60 | Time: 00:00:00 | Train Loss: 2.9998 | Average Loss: 3.5320
# Accuracy: 0.205729 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.8344 | Average Loss: 3.4768
# Epoch: 3 | Iter:   20 | Time: 00:00:01 | Train Loss: 3.1415 | Average Loss: 3.4169
# Epoch: 3 | Iter:   40 | Time: 00:00:01 | Train Loss: 2.8826 | Average Loss: 3.3642
# Epoch: 3 | Iter:   60 | Time: 00:00:01 | Train Loss: 3.0128 | Average Loss: 3.3276
# Accuracy: 0.294271 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.8580 | Average Loss: 3.3007
# Epoch: 4 | Iter:   20 | Time: 00:00:01 | Train Loss: 3.0005 | Average Loss: 3.2691
# Epoch: 4 | Iter:   40 | Time: 00:00:01 | Train Loss: 2.7131 | Average Loss: 3.2416
# Epoch: 4 | Iter:   60 | Time: 00:00:01 | Train Loss: 2.8339 | Average Loss: 3.2173
# Accuracy: 0.291667 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:02 | Train Loss: 2
| Time: 00:00:00

# %% [markdown]
# **Answer**:
#
# Technique 1:
#
# features:
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#
#     (1): Sigmoid()
#
#     (2): ReLU()
#
#     (3): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#
#     (4): Dropout(p=0.5, inplace=False)
#
#
# classifier:
#
#     (0): Linear(in_features=7200, out_features=400, bias=True)
#
#     (1): BatchNorm1d(400, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#     (2): Linear(in_features=400, out_features=32, bias=True)
#
#     (3): Dropout(p=0.5, inplace=False)
#
#
#
# Accuracy on test set: 0.453125
#
# Accuracy increases/decreases: decreases

# %% [markdown]
# ### Technique 2

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=True, zero_centered=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 75 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------

class Hw4NetT2(nn.Module):
    def __init__(self):
      super(Hw4NetT2,self).__init__()  
           
      self.features = torch.nn.Sequential(
        nn.Conv2d(1, 32, 3),
          nn.ReLU(),
          nn.Conv2d(32, 64, 3),
          nn.ReLU(),
          nn.MaxPool2d(4, stride=4),   
          nn.BatchNorm2d(64),
          nn.Dropout(0.5)
      )
      
      self.classifier = nn.Sequential(
         nn.Linear(3600 * 4, 200), 
         nn.BatchNorm1d(200),
         nn.Linear(200,64),
         nn.Dropout(0.5),

      )
      
    def forward(self, x):
      x = self.features(x)  
      x = torch.flatten(x, 1)
      x = self.classifier(x)
      return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
hwnet2 = Hw4NetT2() 
train_option = {}
train_option['lr'] = 0.002
train_option['epoch'] = 20
train_option['device'] = 'gpu'
print(hwnet2)
trainModel(hwnet2, trainloader_small, train_option, testloader_small)
# Out:
# Hw4NetT2(
#   (features): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): Dropout(p=0.5, inplace=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=14400, out_features=200, bias=True)
#     (1): BatchNorm1d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Linear(in_features=200, out_features=64, bias=True)
#     (3): Dropout(p=0.5, inplace=False)
#   )
# )
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 4.6903 | Average Loss: 4.6903
# Epoch: 1 | Iter:   20 | Time: 00:00:00 | Train Loss: 3.6332 | Average Loss: 4.1231
# Epoch: 1 | Iter:   40 | Time: 00:00:00 | Train Loss: 3.1579 | Average Loss: 3.7973
# Epoch: 1 | Iter:   60 | Time: 00:00:01 | Train Loss: 2.9127 | Average Loss: 3.6441
# Accuracy: 0.390625 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:01 | Train Loss: 3.2903 | Average Loss: 3.5524
# Epoch: 2 | Iter:   20 | Time: 00:00:01 | Train Loss: 3.1004 | Average Loss: 3.4389
# Epoch: 2 | Iter:   40 | Time: 00:00:02 | Train Loss: 2.8616 | Average Loss: 3.3345
# Epoch: 2 | Iter:   60 | Time: 00:00:02 | Train Loss: 2.4783 | Average Loss: 3.2545
# Accuracy: 0.447917 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:02 | Train Loss: 2.5815 | Average Loss: 3.1984
# Epoch: 3 | Iter:   20 | Time: 00:00:03 | Train Loss: 2.5128 | Average Loss: 3.1456
# Epoch: 3 | Iter:   40 | Time: 00:00:03 | Train Loss: 2.4533 | Average Loss: 3.0874
# Epoch: 3 | Iter:   60 | Time: 00:00:03 | Train Loss: 2.4417 | Average Loss: 3.0412
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:04 | Train Loss: 2.5110 | Average Loss: 3.0059
# Epoch: 4 | Iter:   20 | Time: 00:00:04 | Train Loss: 2.6219 | Average Loss: 2.9653
# Epoch: 4 | Iter:   40 | Time: 00:00:04 | Train Loss: 2.3491 | Average Loss: 2.9238
# Epoch: 4 | Iter:   60 | Time: 00:00:05 | Train Loss: 2.2505 | Average Loss: 2.8904
# Accuracy: 0.609375 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:05 | Train Loss: 2.6103 | Average Loss: 2.8663
# Epoch: 5 | Iter:   20 | Time: 00:00:05 | Train Loss: 1.9315 | Average Loss: 2.8375
# Epoch: 5 | Iter:   40 | Time: 00:00:06 | Train Loss: 1.9709 | Average Loss: 2.8088
# Epoch: 5 | Iter:   60 | Time: 00:00:06 | Train Loss: 2.3975 | Average Loss: 2.7825
# Accuracy: 0.596354 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00
5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#     (6): Dropout(p=0.5, inplace=False)
#
#
#
# classifier:
#
#     (0): Linear(in_features=14400, out_features=200, bias=True)
#
#     (1): BatchNorm1d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#     (2): Linear(in_features=200, out_features=64, bias=True)
#
#     (3): Dropout(p=0.5, inplace=False)
#
# Accuracy on test set:  0.645833
#
# Accuracy increases/decreases: increases

# %% [markdown]
# ### Technique 3

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=True, zero_centered=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 75 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------

class Hw4NetT3(nn.Module):
    def __init__(self):
      super(Hw4NetT3,self).__init__()  
        
      self.features = torch.nn.Sequential(
          nn.Conv2d(1, 64, 3),
          nn.ReLU(),
          nn.MaxPool2d(4, stride=4), 
          nn.Dropout(0.6),
          nn.BatchNorm2d(64)
      )
      
      self.classifier = nn.Sequential(
         nn.Linear(64*15*15, 300), 
         nn.BatchNorm1d(300),
         nn.Dropout(0.5),
         nn.Linear(300,32)

      )
      
    def forward(self, x):
      x = self.features(x)  
      # print(x.shape)
      x = torch.flatten(x, 1)
      x = self.classifier(x)
      return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
hwnet_bn = Hw4NetT3() 
train_option = {}
train_option['lr'] = 0.002
train_option['epoch'] = 20
train_option['device'] = 'gpu'
print(hwnet_bn)
trainModel(hwnet_bn, trainloader_small, train_option, testloader_small)
# Out:
# Hw4NetT3(
#   (features): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (3): Dropout(p=0.6, inplace=False)
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=14400, out_features=300, bias=True)
#     (1): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=300, out_features=32, bias=True)
#   )
# )
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.7081 | Average Loss: 3.7081
# Epoch: 1 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.5171 | Average Loss: 2.8236
# Epoch: 1 | Iter:   40 | Time: 00:00:00 | Train Loss: 2.4384 | Average Loss: 2.5828
# Epoch: 1 | Iter:   60 | Time: 00:00:00 | Train Loss: 1.8817 | Average Loss: 2.4274
# Accuracy: 0.471354 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.2439 | Average Loss: 2.3591
# Epoch: 2 | Iter:   20 | Time: 00:00:00 | Train Loss: 1.5441 | Average Loss: 2.2089
# Epoch: 2 | Iter:   40 | Time: 00:00:01 | Train Loss: 1.6757 | Average Loss: 2.1012
# Epoch: 2 | Iter:   60 | Time: 00:00:01 | Train Loss: 1.2612 | Average Loss: 2.0051
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.0080 | Average Loss: 1.9555
# Epoch: 3 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.2776 | Average Loss: 1.8696
# Epoch: 3 | Iter:   40 | Time: 00:00:01 | Train Loss: 1.3968 | Average Loss: 1.8028
# Epoch: 3 | Iter:   60 | Time: 00:00:01 | Train Loss: 1.0397 | Average Loss: 1.7422
# Accuracy: 0.596354 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.8147 | Average Loss: 1.7061
# Epoch: 4 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.0732 | Average Loss: 1.6536
# Epoch: 4 | Iter:   40 | Time: 00:00:02 | Train Loss: 1.1330 | Average Loss: 1.6059
# Epoch: 4 | Iter:   60 | Time: 00:00:02 | Train Loss: 0.9431 | Average Loss: 1.5641
# Accuracy: 0.604167 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.8863 | Average Loss: 1.5384
# Epoch: 5 | Iter:   20 | Time: 00:00:02 | Train Loss: 0.7736 | Average Loss: 1.4989
# Epoch: 5 | Iter:   40 | Time: 00:00:03 | Train Loss: 1.0897 | Average Loss: 1.4652
# Epoch: 5 | Iter:   60 | Time: 00:00:03 | Train Loss: 0.7893 | Average Loss: 1.4319
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:03 | Train Loss: 0
# Accuracy: 0.611979 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.3824 | Average Loss: 0.8263
# Epoch:17 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.3462 | Average Loss: 0.8197
# Epoch:17 | Iter:   40 | Time: 00:00:11 | Train Loss: 0.3294 | Average Loss: 0.8130
# Epoch:17 | Iter:   60 | Time: 00:00:11 | Train Loss: 0.4090 | Average Loss: 0.8066
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.3662 | Average Loss: 0.8014
# Epoch:18 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.4254 | Average Loss: 0.7950
# Epoch:18 | Iter:   40 | Time: 00:00:12 | Train Loss: 0.4659 | Average Loss: 0.7889
# Epoch:18 | Iter:   60 | Time: 00:00:12 | Train Loss: 0.2079 | Average Loss: 0.7824
# Accuracy: 0.601562 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.2145 | Average Loss: 0.7778
# Epoch:19 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.3293 | Average Loss: 0.7723
# Epoch:19 | Iter:   40 | Time: 00:00:12 | Train Loss: 0.5251 | Average Loss: 0.7666
# Epoch:19 | Iter:   60 | Time: 00:00:12 | Train Loss: 0.1749 | Average Loss: 0.7611
# Accuracy: 0.611979 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.3836 | Average Loss: 0.7571
# Epoch:20 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.5484 | Average Loss: 0.7514
# Epoch:20 | Iter:   40 | Time: 00:00:13 | Train Loss: 0.4262 | Average Loss: 0.7462
# Epoch:20 | Iter:   60 | Time: 00:00:13 | Train Loss: 0.2052 | Average Loss: 0.7403
# Accuracy: 0.604167 | Time: 00:00:00

# %% [markdown]
# **Answer**:
#
# Technique 3:
# features:
#
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1))
#
#     (1): ReLU()
#
#     (2): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#
#     (3): Dropout(p=0.6, inplace=False)
#
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#  classifier:
#
#     (0): Linear(in_features=14400, out_features=300, bias=True)
#
#     (1): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#     (2): Dropout(p=0.5, inplace=False)
#
#     (3): Linear(in_features=300, out_features=32, bias=True)
#
#   )
#
# Accuracy on test set:
#
# Accuracy increases/decreases:

# %% [markdown]
# ## Problem 2: Fine Tuning a Pre-Trained Deep Network
# Our convolutional network to this point isn't "deep". Fortunately, the representations learned by deep convolutional networks is that they generalize surprisingly well to other recognition tasks.
#
# But how do we use an existing deep network for a new recognition task? Take for instance,  [AlexNet](http://papers.nips.cc/paper/4824-imagenet-classification-with-deep-convolutional-neural-networks) network has 1000 units in the final layer corresponding to 1000 ImageNet categories.
#
#
# **Hints**:
# - Many pre-trained models are available in PyTorch at [here](http://pytorch.org/docs/master/torchvision/models.html).
# - For fine-tuning pretrained network using PyTorch, please read this [tutorial](http://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html).

# %% [markdown]
# ### Problem 2.1
#
# **Strategy A**: *Fine-tune* an existing network. In this scenario you take an existing network, replace the final layer (or more) with random weights, and train the entire network again with images and ground truth labels for your recognition task. You are effectively treating the pre-trained deep network as a better initialization than the random weights used when training from scratch. When you don't have enough training data to train a complex network from scratch (e.g. with the 16 classes) this is an attractive option. Fine-tuning can work far better than Strategy B of taking the activations directly from an pre-trained CNN. For example, in [this paper](http://www.cc.gatech.edu/~hays/papers/deep_geo.pdf) from CVPR 2015, there wasn't enough data to train a deep network from scratch, but fine tuning led to 4 times higher accuracy than using off-the-shelf networks directly.
#
# (25 points) You are required to implement Strategy A to fine-tune a pre-trained **AlexNet** for this scene classification task. You should be able to achieve accuracy of **0.85** approximately. The minimum accuracy required for this section is **0.75**.
#
# Please provide detailed descriptions of:<br>
# (1) which layers of AlexNet have been replaced<br>
# (2) the architecture of the new layers added including activation methods (same as problem 1)<br>
# (3) the final accuracy on test set <br>

# %%
# reload data with a larger size
img_size = (128, 128)
batch_size = 64 # training sample number per batch 

# load training dataset
trainloader_large = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, 
                                      augment=True, is_color=True, zero_centered=True))
train_num = len(trainloader_large)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_large = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, is_color=True, zero_centered=True))
test_num = len(testloader_large)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 75 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Fine-Tune Pretrained Network
#--------------------------------------------------
from torchvision import models
alexnet = models.alexnet(pretrained=True)
alexnet.classifier[4] = nn.BatchNorm1d(4096)
alexnet.classifier[6] = nn.Linear(4096, 16)

alexnet_train = {}
alexnet_train['lr'] = 0.0001
alexnet_train['epoch'] = 25
alexnet_train['device'] = 'gpu'

print(alexnet)
trainModel(alexnet, trainloader_large, alexnet_train, testloader_large)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): BatchNorm1d(4096, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=16, bias=True)
#   )
# )
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.9953 | Average Loss: 2.9953
# Epoch: 1 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.5878 | Average Loss: 2.2276
# Epoch: 1 | Iter:   40 | Time: 00:00:01 | Train Loss: 1.1966 | Average Loss: 1.8415
# Epoch: 1 | Iter:   60 | Time: 00:00:02 | Train Loss: 1.1163 | Average Loss: 1.6089
# Accuracy: 0.721354 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.8032 | Average Loss: 1.4882
# Epoch: 2 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.6788 | Average Loss: 1.3449
# Epoch: 2 | Iter:   40 | Time: 00:00:05 | Train Loss: 0.6848 | Average Loss: 1.2449
# Epoch: 2 | Iter:   60 | Time: 00:00:06 | Train Loss: 0.7635 | Average Loss: 1.1616
# Accuracy: 0.791667 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.5199 | Average Loss: 1.1088
# Epoch: 3 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.4443 | Average Loss: 1.0405
# Epoch: 3 | Iter:   40 | Time: 00:00:08 | Train Loss: 0.5272 | Average Loss: 0.9830
# Epoch: 3 | Iter:   60 | Time: 00:00:09 | Train Loss: 0.4977 | Average Loss: 0.9340
# Accuracy: 0.786458 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.4196 | Average Loss: 0.9006
# Epoch: 4 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.2138 | Average Loss: 0.8572
# Epoch: 4 | Iter:   40 | Time: 00:00:12 | Train Loss: 0.3573 | Average Loss: 0.8187
# Epoch: 4 | Iter:   60 | Time: 00:00:13 | Train Loss: 0.3563 | Average Loss: 0.7831
# Accuracy: 0.794271 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.2292 | Average Loss: 0.7588
# Epoch: 5 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.2020 | Average Loss: 0.7276
# Epoch: 5 | Iter:   40 | Time: 00:00:15 | Train Loss: 0.2612 | Average Loss: 0.6987
# Epoch: 5 | Iter:   60 | Time: 00:00:16 | Train Loss: 0.2231 | Average Loss: 0.6716
# Accuracy: 0.807292 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.1210 | Average Loss: 0.6529
# Epoch: 6 | Iter:   20 | Time: 00:00:18 | Train Loss: 0.0798 | Average Loss: 0.6279
# Epoch: 6 | Iter:   40 | Time: 00:00:19 | Train Loss: 0.1582 | Average Loss: 0.6048
# Epoch: 6 | Iter:   60 | Time: 00:00:20 | Train Loss: 0.1785 | Average Loss: 0.5833
# Accuracy: 0.794271 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.
| Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:01:13 | Train Loss: 0.0024 | Average Loss: 0.1778
# Epoch:22 | Iter:   20 | Time: 00:01:14 | Train Loss: 0.0022 | Average Loss: 0.1756
# Epoch:22 | Iter:   40 | Time: 00:01:15 | Train Loss: 0.0025 | Average Loss: 0.1735
# Epoch:22 | Iter:   60 | Time: 00:01:16 | Train Loss: 0.0031 | Average Loss: 0.1714
# Accuracy: 0.812500 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:01:17 | Train Loss: 0.0022 | Average Loss: 0.1699
# Epoch:23 | Iter:   20 | Time: 00:01:17 | Train Loss: 0.0030 | Average Loss: 0.1679
# Epoch:23 | Iter:   40 | Time: 00:01:18 | Train Loss: 0.0024 | Average Loss: 0.1659
# Epoch:23 | Iter:   60 | Time: 00:01:19 | Train Loss: 0.0027 | Average Loss: 0.1640
# Accuracy: 0.817708 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:01:20 | Train Loss: 0.0023 | Average Loss: 0.1626
# Epoch:24 | Iter:   20 | Time: 00:01:21 | Train Loss: 0.0021 | Average Loss: 0.1608
# Epoch:24 | Iter:   40 | Time: 00:01:22 | Train Loss: 0.0019 | Average Loss: 0.1590
# Epoch:24 | Iter:   60 | Time: 00:01:23 | Train Loss: 0.0030 | Average Loss: 0.1572
# Accuracy: 0.815104 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:01:24 | Train Loss: 0.0018 | Average Loss: 0.1559
# Epoch:25 | Iter:   20 | Time: 00:01:24 | Train Loss: 0.0017 | Average Loss: 0.1542
# Epoch:25 | Iter:   40 | Time: 00:01:25 | Train Loss: 0.0019 | Average Loss: 0.1526
# Epoch:25 | Iter:   60 | Time: 00:01:26 | Train Loss: 0.0021 | Average Loss: 0.1510
# Accuracy: 0.815104 | Time: 00:00:00

# %% [markdown]
# **Answer**:
#
# (1) which layers of AlexNet have been replaced
# Classifier 4 and 6 were replaced
#
#
# (2) the architecture of the new layers added including activation methods (same as problem 1)
#
# Data augmentation: Flip/mirror images to increase the training set.
#
# Data normalization: Subtract mean from every image
#
# Features Layers :
# features:
#
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#
#     (1): ReLU(inplace=True)
#
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#
#     (4): ReLU(inplace=True)
#
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#
#     (7): ReLU(inplace=True)
#
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#
#     (9): ReLU(inplace=True)
#
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#
#     (11): ReLU(inplace=True)
#
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#
#
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#
#   classifier:
#     (0): Dropout(p=0.5, inplace=False)
#
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#
#     (2): ReLU(inplace=True)
#
#     (3): Dropout(p=0.5, inplace=False)
#
#     (4): BatchNorm1d(4096, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#     (5): ReLU(inplace=True)
#
#     (6): Linear(in_features=4096, out_features=16, bias=True)
#
#
# (3) the final accuracy on test set
#
# Accuracy on test set: 0.828125

# %% [markdown]
# ### Problem 2.2
# **Strategy B**: One could use those 1000 activations as a feature in place of a hand crafted feature such as a bag-of-features representation. You would train a classifier (typically a linear SVM) in that 1000 dimensional feature space. However, those activations are clearly very object specific and may not generalize well to new recognition tasks. It is generally better to use the activations in slightly earlier layers of the network, e.g. the 4096 activations in the last 2nd fully-connected layer. You can often get away with sub-sampling those 4096 activations considerably, e.g. taking only the first 1000 activations.
#
# (25 points) Implement Strategy B where you use the activations of the pre-trained **AlexNet** as features to train **one-vs-all SVMs** for your scene classification task. Report the final accuracy on test set. You should be able to achieve accuracy of **0.80** approximately. The minimum accuracy required for this section is **0.70**.

# %%
#--------------------------------------------------
#       Get Features from AlexNet
#--------------------------------------------------


ft = torchvision.models.alexnet(pretrained=True)
del ft.classifier[-1]
ft.eval()
def get_ft(data_loader_):
    image_list = []
    list_l = []
    for i, l in data_loader_:
        image_list.extend(ft(i.float())[:, :1000].detach().numpy())
        list_l.extend(l.detach().numpy())
    return np.vstack(image_list), np.hstack(list_l)
ft_train, lab_train = get_ft(trainloader_large)
test_feat, test_label = get_ft(testloader_large)

# %%
#--------------------------------------------------
#       Train and Evaluate SVM
#--------------------------------------------------
from sklearn import svm
clf = svm.SVC(kernel='rbf')
clf.fit(ft_train, lab_train)

train_acc = sum(np.array(clf.predict(ft_train)) == train_label) / float(len(train_label))
test_acc = sum(np.array(clf.predict(test_feat)) == test_label) / float(len(test_label))
print(f"Accuracy of AlexNet feature + one-vs-all SVM - test set: {test_acc:.5f} ")
# Out:
# Accuracy of AlexNet feature + one-vs-all SVM - test set: 0.74740

# %% [markdown]
# **Answer**:
#
# Accuracy on test set: 0.74740

# %% [markdown]
# ### Problem 2.3 (Bonus)
#
# (Bonus: 10 points) Bonus will be given to those who fine-tune the [ResNet network](https://pytorch.org/docs/stable/_modules/torchvision/models/resnet.html) [(paper)](https://arxiv.org/abs/1512.03385) and compare performance with AlexNet. Explain why ResNet performed better or worse. You are **required** to use **resnet50** model. You should be able to achieve accuracy of **0.99** approximately. The minimum accuracy required for this section is **0.85**.

# %%
#--------------------------------------------------
#       Fine-Tune Pretrained Network
#--------------------------------------------------
from torchvision import models
res = models.resnet50(pretrained=True)
res.fc = nn.Linear(2048,16)

resnet_train = {}
resnet_train["lr"] = 0.0001
resnet_train["epoch"] = 13
resnet_train["device"] = "gpu"
#remove next line
# print(net)
trainModel(res, trainloader_large, resnet_train, testloader_large)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# HBox(children=(FloatProgress(value=0.0, max=102502400.0), HTML(value='')))
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.7237 | Average Loss: 2.7237
# Epoch: 1 | Iter:   20 | Time: 00:00:05 | Train Loss: 1.1583 | Average Loss: 1.7740
# Epoch: 1 | Iter:   40 | Time: 00:00:10 | Train Loss: 0.4563 | Average Loss: 1.2380
# Epoch: 1 | Iter:   60 | Time: 00:00:15 | Train Loss: 0.3877 | Average Loss: 0.9712
# Accuracy: 0.856771 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.3921 | Average Loss: 0.8556
# Epoch: 2 | Iter:   20 | Time: 00:00:24 | Train Loss: 0.2154 | Average Loss: 0.7191
# Epoch: 2 | Iter:   40 | Time: 00:00:29 | Train Loss: 0.0415 | Average Loss: 0.6110
# Epoch: 2 | Iter:   60 | Time: 00:00:35 | Train Loss: 0.0630 | Average Loss: 0.5285
# Accuracy: 0.867188 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:39 | Train Loss: 0.0486 | Average Loss: 0.4809
# Epoch: 3 | Iter:   20 | Time: 00:00:44 | Train Loss: 0.0145 | Average Loss: 0.4274
# Epoch: 3 | Iter:   40 | Time: 00:00:49 | Train Loss: 0.0211 | Average Loss: 0.3843
# Epoch: 3 | Iter:   60 | Time: 00:00:55 | Train Loss: 0.0057 | Average Loss: 0.3490
# Accuracy: 0.903646 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00
| Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:03:16 | Train Loss: 0.1154 | Average Loss: 0.1196
# Epoch:11 | Iter:   20 | Time: 00:03:21 | Train Loss: 0.0658 | Average Loss: 0.1177
# Epoch:11 | Iter:   40 | Time: 00:03:26 | Train Loss: 0.1149 | Average Loss: 0.1160
# Epoch:11 | Iter:   60 | Time: 00:03:31 | Train Loss: 0.0836 | Average Loss: 0.1141
# Accuracy: 0.854167 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:03:36 | Train Loss: 0.0361 | Average Loss: 0.1128
# Epoch:12 | Iter:   20 | Time: 00:03:41 | Train Loss: 0.0257 | Average Loss: 0.1109
# Epoch:12 | Iter:   40 | Time: 00:03:46 | Train Loss: 0.0117 | Average Loss: 0.1092
# Epoch:12 | Iter:   60 | Time: 00:03:51 | Train Loss: 0.0141 | Average Loss: 0.1075
# Accuracy: 0.846354 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:03:55 | Train Loss: 0.0059 | Average Loss: 0.1059
# Epoch:13 | Iter:   20 | Time: 00:04:00 | Train Loss: 0.0278 | Average Loss: 0.1041
# Epoch:13 | Iter:   40 | Time: 00:04:06 | Train Loss: 0.0121 | Average Loss: 0.1022
# Epoch:13 | Iter:   60 | Time: 00:04:11 | Train Loss: 0.0033 | Average Loss: 0.1002
# Accuracy: 0.880208 | Time: 00:00:00

# %% [markdown]
# **Answer**:
#
# Accuracy on test set: 0.903646

# %% [markdown]
# ## Submission guidelines
# ---
# Extract the downloaded .zip file to a folder of your preference. The input and output paths are predefined and **DO NOT** change them, (we assume that 'Surname_Givenname_SBUID_hw4' is your working directory, and all the paths are relative to this directory).  The image read and write functions are already written for you. All you need to do is to fill in the blanks as indicated to generate proper outputs. **DO NOT** zip and upload the dataset on blackboard due to size limit.
#
# When submitting your .zip file through blackboard, please
# -- name your .zip file as **Surname_Givenname_SBUID_hw*.zip**.
#
# This zip file should include:
# ```
# Surname_Givenname_SBUID_hw*
#         |---Surname_Givenname_SBUID_hw*.ipynb
#         |---Surname_Givenname_SBUID_hw*.pdf
# ```
#
# For instance, student Yann LeCun should submit a zip file named "LeCun_Yann_111134567_hw4.zip" for homework4 in this structure:
# ```
# LeCun_Yann_111134567_hw4
#         |---LeCun_Yann_111134567_hw4.ipynb
#         |---LeCun_Yann_111134567_hw4.pdf
# ```
#
# The **Surname_Givenname_SBUID_hw*.pdf** should include a **google shared link**. To generate the **google shared link**, first create a folder named **Surname_Givenname_SBUID_hw*** in your Google Drive with your Stony Brook account. The structure of the files in the folder should be exactly the same as the one you downloaded. If you alter the folder structures, the grading of your homework will be significantly delayed and possibly penalized.
#
# Then right click this folder, click ***Get shareable link***, in the People textfield, enter TA's emails. Make sure that TAs who have the link **can edit**, ***not just*** **can view**, and also **uncheck** the **Notify people** box.
#
# Colab has a good feature of version control, you should take advantage of this to save your work properly. However, the timestamp of the submission made in blackboard is the only one that we consider for grading. To be more specific, we will only grade the version of your code right before the timestamp of the submission made in blackboard.
#
# You are encouraged to post and answer questions on Piazza. Based on the amount of email that we have received in past years, there might be dealys in replying to personal emails. Please ask questions on Piazza and send emails only for personal issues.
#
# Be aware that your code will undergo plagiarism check both vertically and horizontally. Please do your own work.
#
# **Late submission penalty:** <br>
# There will be a 10% penalty per day for late submission. However, you will have 4 days throughout the whole semester to submit late without penalty. Note that the grace period is calculated by days instead of hours. If you submit the homework one minute after the deadline, one late day will be counted. Likewise, if you submit one minute after the deadline, the 10% penaly will be imposed if not using the grace period.

# %% [markdown]
# <!--Write your report here in markdown or html-->
